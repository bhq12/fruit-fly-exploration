# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
cardinality_data = [
    {"model": 'Random Selection', "cardinality": 2, "test_set_accuracy": 0.5},
    {"model": 'Random Selection', "cardinality": 4, "test_set_accuracy": 0.25},
    {"model": 'Random Selection', "cardinality": 5, "test_set_accuracy": 0.2},
    {"model": 'Random Selection', "cardinality": 10, "test_set_accuracy": 0.1},
    {"model": 'Random Selection', "cardinality": 20, "test_set_accuracy": 0.05},
    
    {"model": 'Decision Tree', "cardinality": 2, "test_set_accuracy": 0.82},
    {"model": 'Decision Tree', "cardinality": 2, "test_set_accuracy": 0.65},
    {"model": 'Decision Tree', "cardinality": 4, "test_set_accuracy": 0.51},
    {"model": 'Decision Tree', "cardinality": 5, "test_set_accuracy": 0.23},
    {"model": 'Decision Tree', "cardinality": 10, "test_set_accuracy": 0.13},
    {"model": 'Decision Tree', "cardinality": 10, "test_set_accuracy": 0.18},
    {"model": 'Decision Tree', "cardinality": 20, "test_set_accuracy": 0.11},

    {"model": 'Softmax', "cardinality": 2, "test_set_accuracy": 0.86},
    {"model": 'Softmax', "cardinality": 2, "test_set_accuracy": 0.70},
    {"model": 'Softmax', "cardinality": 4, "test_set_accuracy": 0.65},
    {"model": 'Softmax', "cardinality": 5, "test_set_accuracy": 0.29},
    {"model": 'Softmax', "cardinality": 10, "test_set_accuracy": 0.21},
    {"model": 'Softmax', "cardinality": 10, "test_set_accuracy": 0.24},
    {"model": 'Softmax', "cardinality": 20, "test_set_accuracy": 0.16},

    {"model": 'Neural Network', "cardinality": 2, "test_set_accuracy": 0.83},
    {"model": 'Neural Network', "cardinality": 2, "test_set_accuracy": 0.69},
    {"model": 'Neural Network', "cardinality": 4, "test_set_accuracy": 0.56},
    {"model": 'Neural Network', "cardinality": 5, "test_set_accuracy": 0.26},
    {"model": 'Neural Network', "cardinality": 10, "test_set_accuracy": 0.19},
    {"model": 'Neural Network', "cardinality": 10, "test_set_accuracy": 0.23},
    {"model": 'Neural Network', "cardinality": 20, "test_set_accuracy": 0.15},

    
]

cardinality_data_frame = pd.DataFrame(cardinality_data)

#cardinality_data_frame.plot(x='cardinality', y='test_set_accuracy')
sns.scatterplot(data=cardinality_data_frame, x="cardinality", y="test_set_accuracy", hue="model")
# Out:
# <Axes: xlabel='cardinality', ylabel='test_set_accuracy'>
