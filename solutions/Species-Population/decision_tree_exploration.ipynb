# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Import the data set

# %%
lab_data = pd.read_csv('../../data/83_Loeschcke_et_al_2000_Thorax_&_wing_traits_lab pops.csv')

# %% [markdown]
# # Data Cleaning

# %%
lab_data = pd.read_csv('../data/83_Loeschcke_et_al_2000_Thorax_&_wing_traits_lab pops.csv')

# Data cleaning
erroneous = lab_data[lab_data['Thorax_length'] == '.']
erroneous
# Out:
#          Species     Population  Latitude  Longitude  Year_start  Year_end  \
# 253  D._aldrichi  Gogango_Creek    -23.77     150.17        1994      1994
#
#      Temperature  Vial  Replicate     Sex Thorax_length    l2    l3p    l3d  \
# 253           25     6          3  female             .  1.65  0.573  1.415
#
#        lpd     l3     w1     w2     w3 wing_loading
# 253  1.988  1.986  0.898  1.207  1.003            .

# %%
similar_rows = lab_data[
    (lab_data['Species'] == 'D._aldrichi')
    & (lab_data['Population'] == 'Gogango_Creek')
    & (lab_data['Sex'] == 'female')
    & (lab_data['Thorax_length'] != ".")
]
similar_rows['Thorax_length'] = pd.to_numeric(similar_rows['Thorax_length'])
similar_rows.head()
# Out:
# /var/folders/j_/9f1md2vd0_s6kpn12szf1t2c0000gn/T/ipykernel_67286/3776846164.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   similar_rows['Thorax_length'] = pd.to_numeric(similar_rows['Thorax_length'])
#          Species     Population  Latitude  Longitude  Year_start  Year_end  \
# 162  D._aldrichi  Gogango_Creek    -23.77     150.17        1994      1994
# 164  D._aldrichi  Gogango_Creek    -23.77     150.17        1994      1994
# 166  D._aldrichi  Gogango_Creek    -23.77     150.17        1994      1994
# 167  D._aldrichi  Gogango_Creek    -23.77     150.17        1994      1994
# 169  D._aldrichi  Gogango_Creek    -23.77     150.17        1994      1994
#
#      Temperature  Vial  Replicate     Sex  Thorax_length     l2    l3p    l3d  \
# 162           20     1          1  female          1.166  1.910  0.578  1.675
# 164           20     1          2  female          1.174  1.829  0.622  1.549
# 166           20     1          3  female          1.199  1.864  0.585  1.659
# 167           20     2          1  female          1.186  1.872  0.628  1.571
# 169           20     2          2  female          1.176  1.872  0.630  1.579
#
#        lpd     l3     w1     w2     w3 wing_loading
# 162  2.254  2.252  0.982  1.381  1.123        1.932
# 164  2.170  2.170  0.997  1.360  1.117        1.848
# 166  2.244  2.242  1.009  1.376  1.142        1.870
# 167  2.199  2.199  1.002  1.356  1.143        1.854
# 169  2.207  2.207  0.966  1.345  1.103        1.876

# %%
similar_row_median = similar_rows['Thorax_length'].median()

lab_data['Thorax_length'] = lab_data.apply(
    lambda x: (x['Thorax_length'] if x['Thorax_length'] != "." else similar_row_median),
    axis=1
)
lab_data.head()

lab_data['wing_loading'] = lab_data.apply(
    lambda x: (x['wing_loading'] if x['wing_loading'] != "." else round((x['l3'] / x['Thorax_length']), 3)),
    axis=1
)

print(len(similar_rows))
print(similar_row_median)

lab_data.loc[253]
# Out:
# 87
# 1.141
# Species            D._aldrichi
# Population       Gogango_Creek
# Latitude                -23.77
# Longitude               150.17
# Year_start                1994
# Year_end                  1994
# Temperature                 25
# Vial                         6
# Replicate                    3
# Sex                     female
# Thorax_length            1.141
# l2                        1.65
# l3p                      0.573
# l3d                      1.415
# lpd                      1.988
# l3                       1.986
# w1                       0.898
# w2                       1.207
# w3                       1.003
# wing_loading             1.741
# Name: 253, dtype: object

# %% [markdown]
# # Model Building

# %%
lab_data['Thorax_length'] = pd.to_numeric(lab_data['Thorax_length'])
lab_data['wing_loading'] = pd.to_numeric(lab_data['wing_loading'])

# %%
lab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1730 entries, 0 to 1730
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Species        1730 non-null   object
#  1   Population     1730 non-null   object
#  2   Latitude       1730 non-null   float64
#  3   Longitude      1730 non-null   float64
#  4   Year_start     1730 non-null   int64
#  5   Year_end       1730 non-null   int64
#  6   Temperature    1730 non-null   int64
#  7   Vial           1730 non-null   int64
#  8   Replicate      1730 non-null   int64
#  9   Sex            1730 non-null   object
#  10  Thorax_length  1730 non-null   float64
#  11  l2             1730 non-null   float64
#  12  l3p            1730 non-null   float64
#  13  l3d            1730 non-null   float64
#  14  lpd            1730 non-null   float64
#  15  l3             1730 non-null   float64
#  16  w1             1730 non-null   float64
#  17  w2             1730 non-null   float64
#  18  w3             1730 non-null   float64
#  19  wing_loading   1730 non-null   float64
# dtypes: float64(12), int64(5), object(3)
# memory usage: 283.8+ KB

# %%
lab_data.head()
# Out:
#        Species Population  Latitude  Longitude  Year_start  Year_end  \
# 0  D._aldrichi    Binjour    -25.52     151.45        1994      1994
# 1  D._aldrichi    Binjour    -25.52     151.45        1994      1994
# 2  D._aldrichi    Binjour    -25.52     151.45        1994      1994
# 3  D._aldrichi    Binjour    -25.52     151.45        1994      1994
# 4  D._aldrichi    Binjour    -25.52     151.45        1994      1994
#
#    Temperature  Vial  Replicate     Sex  Thorax_length     l2    l3p    l3d  \
# 0           20     1          1  female          1.238  2.017  0.659  1.711
# 1           20     1          1    male          1.113  1.811  0.609  1.539
# 2           20     1          2  female          1.215  1.985  0.648  1.671
# 3           20     1          2    male          1.123  1.713  0.596  1.495
# 4           20     2          1  female          1.218  1.938  0.641  1.658
#
#      lpd     l3     w1     w2     w3  wing_loading
# 0  2.370  2.370  1.032  1.441  1.192         1.914
# 1  2.148  2.146  0.938  1.299  1.066         1.928
# 2  2.319  2.319  0.991  1.396  1.142         1.908
# 3  2.091  2.088  0.958  1.286  1.062         1.860
# 4  2.298  2.298  1.010  1.418  1.148         1.886

# %%
#TODO: Currently using decision tree so no need to normalise, but must do for other methods

# %%
lab_data = shuffle(lab_data)
lab_data['class'] = lab_data.apply(
    lambda x: f"{x['Species']}, {x['Population']}",
    axis=1
)
lab_data.head()
# Out:
#           Species    Population  Latitude  Longitude  Year_start  Year_end  \
# 533   D._aldrichi  Oxford_Downs    -21.77     148.85        1994      1994
# 133   D._aldrichi       Binjour    -25.52     151.45        1994      1994
# 1461  D._buzzatii  Oxford_Downs    -21.77     148.85        1994      1994
# 1580  D._buzzatii       Wahruna    -25.20     151.17        1994      1994
# 671   D._aldrichi  Oxford_Downs    -21.77     148.85        1994      1994
#
#       Temperature  Vial  Replicate     Sex  ...     l2    l3p    l3d    lpd  \
# 533            20     5          1    male  ...  1.850  0.621  1.543  2.165
# 133            30     5          3    male  ...  1.494  0.481  1.360  1.841
# 1461           25     5          3  female  ...  1.899  0.626  1.567  2.193
# 1580           20     5          2    male  ...  1.859  0.651  1.517  2.167
# 671            30    10          2    male  ...  1.544  0.529  1.301  1.831
#
#          l3     w1     w2     w3  wing_loading                      class
# 533   2.163  1.007  1.312  1.186         1.933  D._aldrichi, Oxford_Downs
# 133   1.840  0.794  1.091  0.908         1.865       D._aldrichi, Binjour
# 1461  2.193  0.975  1.350  1.120         1.773  D._buzzatii, Oxford_Downs
# 1580  2.167  0.984  1.353  1.114         1.851       D._buzzatii, Wahruna
# 671   1.831  0.823  1.122  0.935         1.762  D._aldrichi, Oxford_Downs
#
# [5 rows x 21 columns]

# %%
train, test = train_test_split(lab_data, test_size=0.3)

# %%
classifier = DecisionTreeClassifier(criterion='entropy', max_depth=5)
#TODO: Add Thorax Length and wing_loading to this training
classifier.fit(
    train[['Thorax_length', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'wing_loading']],
    train[['class']]
)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
train['class_predictions'] = classifier.predict(train[['Thorax_length', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'wing_loading']])

# %%
train.head()
# Out:
#           Species    Population  Latitude  Longitude  Year_start  Year_end  \
# 476   D._aldrichi  Grandchester    -27.68     152.45        1994      1994
# 1311  D._buzzatii  Grandchester    -27.68     152.45        1994      1994
# 1304  D._buzzatii  Grandchester    -27.68     152.45        1994      1994
# 947   D._buzzatii       Binjour    -25.52     151.45        1994      1994
# 757   D._aldrichi       Wahruna    -25.20     151.17        1994      1994
#
#       Temperature  Vial  Replicate     Sex  ...    l3p    l3d    lpd     l3  \
# 476            30     5          1    male  ...  0.536  1.287  1.823  1.820
# 1311           25    10          1    male  ...  0.598  1.376  1.974  1.974
# 1304           25     9          1  female  ...  0.606  1.559  2.165  2.164
# 947            25     9          1  female  ...  0.655  1.510  2.165  2.164
# 757            25     5          3  female  ...  0.599  1.563  2.162  2.160
#
#          w1     w2     w3  wing_loading                      class  \
# 476   0.847  1.142  0.929         1.714  D._aldrichi, Grandchester
# 1311  0.888  1.213  1.012         1.820  D._buzzatii, Grandchester
# 1304  0.929  1.307  1.063         1.886  D._buzzatii, Grandchester
# 947   0.924  1.311  1.069         1.820       D._buzzatii, Binjour
# 757   0.954  1.288  1.101         1.838       D._aldrichi, Wahruna
#
#                class_predictions
# 476    D._aldrichi, Grandchester
# 1311        D._buzzatii, Binjour
# 1304  D._buzzatii, Gogango_Creek
# 947   D._buzzatii, Gogango_Creek
# 757         D._buzzatii, Binjour
#
# [5 rows x 22 columns]

# %%
#Correct predictions
train.apply(
    lambda x: 1 if x['class_predictions'] == x['class'] else 0,
    axis=1
).sum()
# Out:
# 229

# %%
#Incorrect predictions
train.apply(
    lambda x: 1 if x['class_predictions'] != x['class'] else 0,
    axis=1
).sum()
# Out:
# 982

# %%
# Retry with a deeper depth

# %%
deep_classifier = DecisionTreeClassifier(criterion='entropy', max_depth=10)

deep_classifier.fit(
    train[['Thorax_length', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'wing_loading']],
    train[['class']]
)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10)

# %%
train['deep_class_predictions'] = deep_classifier.predict(train[['Thorax_length', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'wing_loading']])

# %%
#Correct deep predictions
train.apply(
    lambda x: 1 if x['deep_class_predictions'] == x['class'] else 0,
    axis=1
).sum()
# Out:
# 553

# %%
min_leaf_classifier = DecisionTreeClassifier(criterion='entropy', min_samples_leaf=3)

min_leaf_classifier.fit(
    train[['Thorax_length', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'wing_loading']],
    train[['class']]
)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_leaf=3)

# %%
train['min_leaf_predictions'] = min_leaf_classifier.predict(train[['Thorax_length', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'wing_loading']])

# %%
#Correct min_leaf predictions
train.apply(
    lambda x: 1 if x['min_leaf_predictions'] == x['class'] else 0,
    axis=1
).sum()
# Out:
# 750

# %%
fully_fit_classifier = DecisionTreeClassifier(criterion='entropy')

fully_fit_classifier.fit(
    train[['Thorax_length', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'wing_loading']],
    train[['class']]
)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
train['fully_fit_predictions'] = fully_fit_classifier.predict(train[['Thorax_length', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'wing_loading']])

# %%
#Correct fully_fit predictions
train.apply(
    lambda x: 1 if x['fully_fit_predictions'] == x['class'] else 0,
    axis=1
).sum()
# Out:
# 1211

# %%
# Checking the min leaf and fully fit classifiers against the test set

# %%
#Correst min_leaf predictions on the test set

# %%
test['min_leaf_predictions'] = min_leaf_classifier.predict(test[['Thorax_length', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'wing_loading']])
test['fully_fit_predictions'] = fully_fit_classifier.predict(test[['Thorax_length', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'l2', 'l3p', 'wing_loading']])


correct_min_leaf_classification_test = test.apply(
    lambda x: 1 if x['min_leaf_predictions'] == x['class'] else 0,
    axis=1
).sum()

print("Min leaf correct predictions test set:" + str(correct_min_leaf_classification_test))

correct_fully_fit_classification_test = test.apply(
    lambda x: 1 if x['fully_fit_predictions'] == x['class'] else 0,
    axis=1
).sum()

print("Fully fit predictions test set:" + str(correct_fully_fit_classification_test))
# Out:
# Min leaf correct predictions test set:85
# Fully fit predictions test set:78

# %%
print(f"accuracy: {correct_min_leaf_classification_test / len(test)}")
# Out:
# accuracy: 0.16377649325626203
